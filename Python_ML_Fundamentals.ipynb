# %% [markdown]
# # Python and Machine Learning Fundamentals
#
# ## ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) In this lesson you:<br>
#  - Learn Python Fundamentals
#    * Numbers & Strings
#    * Variables
#    * Print statements
#    * Lists
#    * For Loops
#    * Functions
#    * Conditional Statements
#    * Types and Type Checking
#    * What is Machine Learning?
#    * Types of Machine Learning
#    * Train-Test split
#    * Use `sklearn` to build linear regression model
#
# This is a good [reference sheet](https://pi-plates.com/downloads/python_cheat_sheet.pdf) to bookmark. If you want a comprehensive tutorial on how you can use Python, check out this [official tutorial](https://docs.python.org/3/tutorial/) from the Python website.
#
# Here is some documentation to help with [markdown cells](https://forums.databricks.com/static/markdown/help.html).

# %% [markdown]
# ### 1) Numbers: Using Python as your calculator!

# %%
# Hit the run button, or shift + enter
1+1

# %% [markdown]
# ### 2) Strings

# %%
'Ice cream'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[70]: &#39;Ice cream&#39;</div>

# %%
'Ice cream' + 'is paradise'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[71]: &#39;Ice creamis paradise&#39;</div>

# %% [markdown]
# ### 3) Variables
#
# As Shakespeare famously wrote: `A rose by any other name would smell as sweet`. A variable in Python simply holds a value - you can call it any name you want (within reason...)!

# %%
# I like ice cream
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
best_food = 'Ice cream'
best_food
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[73]: &#39;Ice cream&#39;</div>

# %% [markdown]
# ### 4) Print Statements
#
# In Databricks/Jupyter notebooks, it will automatically print out the last line of the cell that it evaluates.
#
# However, we can force it to print out other components by using a `print` statement.

# %%
print("Hi there, tell me the best food.")
print(best_food)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Hi there, tell me the best food.
# Ice cream
# </div>

# %% [markdown]
# You can also be more explicit about what you are printing. You can add your variable within your print statement.

# %%
print(f"{best_food} is the best food on earth.")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Ice cream is the best food on earth.
# </div>

# %% [markdown]
# ### 5) Lists
#
# Let's make a list of what everyone ate for breakfast this morning.
#
# <img src="https://sugarfreelondoner.com/wp-content/uploads/2021/01/Keto-Scrambled-Eggs-1200.jpg" width="20%" height="10%">

# %%
breakfast_list = ["pancakes", "eggs", "waffles"]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
breakfast_list.append("milk")
breakfast_list
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[77]: [&#39;pancakes&#39;, &#39;eggs&#39;, &#39;waffles&#39;, &#39;milk&#39;]</div>

# %% [markdown]
# Let's get the first breakfast element from this list.
#
# **Note:** Everything in Python is 0-indexed, so the first element is at position 0.

# %%
breakfast_list[0]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[78]: &#39;pancakes&#39;</div>

# %% [markdown]
# Let's get the last breakfast item from this list.

# %%
breakfast_list[-1]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[79]: &#39;milk&#39;</div>

# %% [markdown]
# What if I want the second breakfast item and onwards?

# %%
breakfast_list[1:]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[80]: [&#39;eggs&#39;, &#39;waffles&#39;, &#39;milk&#39;]</div>

# %% [markdown]
# ### 6) Conditionals
#
# Sometimes, depending on certain conditions, we don't always want to execute every line of code. We can control this through using the `if`, `elif`, and `else` statements.

# %% [markdown]
# We want print plural forms of a food (try changing `food` to something else)! This requires adding an 's' to the end of a string only if it doesn't already have an 's' there.

# %%
best_food = "chocolate"

if best_food.endswith("s"):
  print(best_food)
else:
  print(best_food + "s")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">chocolates
# </div>

# %% [markdown]
# Try changing `best_food` in the cell below and see the 3 different types of outputs.

# %%
best_food = "ice cream"
ice_cream_count = 1000

if best_food == "ice cream":
  print(f"I want {ice_cream_count} cones of ice cream.")
elif best_food == "":
  print("Tell us your favorite food")
else:
  print("Really? Isn't ice cream better?")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">I want 1000 cones of ice cream.
# </div>

# %% [markdown]
# You can check the equality of the variables by using `==` (equal) or `!=` (not equal).

# %%
best_food == "ice cream"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[83]: True</div>

# %% [markdown]
# ### 7) For Loops
#
# What if we wanted to print every breakfast we had this morning?
#
# Loops are a way to repeat a block of code while iterating over a sequence ("for-loop")

# %%
for food in breakfast_list:
  print(food)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">pancakes
# eggs
# waffles
# milk
# </div>

# %% [markdown]
# What if I want to count how many letters are there in each word?

# %%
for food in breakfast_list:
  print(f"{food} has {len(food)} letters.")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">pancakes has 8 letters.
# eggs has 4 letters.
# waffles has 7 letters.
# milk has 4 letters.
# </div>

# %% [markdown]
# ### 8) Functions
#
# The code above only works with `breakfast_list` but we can generalize it to work with different lists by making a function! A `function` is created with the `def` keyword, followed by the name of the function, any parameters in parentheses, and a colon.

# %%
# General syntax
# def function_name(parameter_name):
#   block of code that is run every time function is called

# defining the function
def print_length(breakfast_list):
  for food in breakfast_list:
    print(f"{food} has {len(food)} letters.")

# execute the function by passing print_length a list
print_length(breakfast_list)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">pancakes has 8 letters.
# eggs has 4 letters.
# waffles has 7 letters.
# milk has 4 letters.
# </div>

# %% [markdown]
# ### 9) Functions with Multiple Arguments
#
# Let's define a function that will add two numbers together.

# %%
ice_cream_count = 1000
chocolate_count = 500

def count_fav_food(ice_cream, chocolate):
  return ice_cream + chocolate

count_fav_food(ice_cream_count, chocolate_count)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[87]: 1500</div>

# %% [markdown]
# What if you know that `chocolate` is always going to be 500? You can set a default value!

# %%
def count_fav_food(ice_cream, chocolate=500):
  return ice_cream + chocolate

count_fav_food(ice_cream_count)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[88]: 1500</div>

# %% [markdown]
# What if you want to calculate the percentage of chocolate to gauge how much you like it?

# %%
def chocolate_percentage(ice_cream, chocolate):
  percentage = chocolate / (ice_cream + chocolate) * 100
  return round(percentage, 2)

percent = chocolate_percentage(ice_cream_count, chocolate_count)
print(f"I like chocolate {percent}% of the time.")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">I like chocolate 33.33% of the time.
# </div>

# %% [markdown]
# If you forget the parameters to a function, you can call `help()`.

# %%
help(count_fav_food)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Help on function count_fav_food in module __main__:
#
# count_fav_food(ice_cream, chocolate=500)
#
# </div>

# %% [markdown]
# ### 10) Types and Type Checking
#
# We have been defining quite a number of variables. What if we forget what types are the variables? Don't worry -- we can always check!
#
# Here are some of the variables we have defined:
# 0. `percent`
# 0. `best_food`
# 0. `breakfast_list`

# %%
type(percent)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[91]: float</div>

# %%
type(best_food)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[92]: str</div>

# %%
type(breakfast_list)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[93]: list</div>

# %% [markdown]
# Summary of types:
# 0. An `int` is a numeric type in Python. It is an integer, so a whole number without decimals.
# 0. A `float` is a numeric type in Python. It is basically a number that has decimal places.
# 0. A `String` type is a sequence of characters, such as the food `"chocolate"`. It can be any sequence of characters too, not just words. `"Hello123"` or even `"123"` could also be a string. They are enclosed in quotes.
# 0. A `Boolean` type is either True or False.

# %% [markdown]
# ### ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Congrats! You have finished your first lesson on Python!

# %% [markdown]
# # Machine Learning with scikit-learn
#
# * What is Machine Learning?
#   * Types of Machine Learning
# * Train-Test split
# * Use `sklearn` to build linear regression model
#
# We will be referencing the [scikit-learn docs](https://scikit-learn.org/stable/user_guide.html) and [pandas docs](https://pandas.pydata.org/pandas-docs/stable/index.html) where relevant, and will be analyzing data from the New York Times COVID-19 US States dataset from https://github.com/nytimes/covid-19-data
#
# **Disclaimer: Linear regression is not the most suitable algorithm for this dataset, but we are using it to illustrate how to use scikit-learn**

# %% [markdown]
# ## What is Machine Learning?
#
# * Learning patterns in your data without being explicitly programmed
# * A function that maps features to an output
#
# ![](https://brookewenig.com/img/DL/al_ml_dl.png)

# %% [markdown]
# -sandbox
# ## Types of Machine Learning
# * Supervised Learning
#   * Regression <img src="https://miro.medium.com/max/640/1*LEmBCYAttxS6uI6rEyPLMQ.png" style="height: 250px; padding: 10px"/>
#   * Classification
#     <img src="https://cdn3-www.dogtime.com/assets/uploads/2018/10/puppies-cover.jpg" style="height: 250px; padding: 10px"/>
#     <img src="https://images.unsplash.com/photo-1529778873920-4da4926a72c2?ixlib=rb-1.2.1&w=1000&q=80" style="height: 250px; padding: 10px"/>
# * Unsupervised Learning
# <img src="https://www.iotforall.com/wp-content/uploads/2018/01/Screen-Shot-2018-01-17-at-8.10.14-PM.png" style="height: 250px; padding: 10px"/>
# * Reinforcement Learning
# <img src="https://brookewenig.com/img/ReinforcementLearning/Rl_agent.png" style="height: 250px; padding: 10px"/>

# %% [markdown]
# Today we're going to start simple and focus on a supervised learning (regression) problem. Here we will use a linear regression model to predict the number of deaths resulting from COVID-19.

# %%
# %fs ls databricks-datasets/COVID/covid-19-data/us-states.csv
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/databricks-datasets/COVID/covid-19-data/us-states.csv</td><td>us-states.csv</td><td>703102</td></tr></tbody></table></div>

# %%
import pandas as pd

df = spark.read.option("header",True).csv("dbfs:/databricks-datasets/COVID/covid-19-data/us-states.csv").toPandas()
df.head()
df.date.max()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[94]: &#39;2021-03-11&#39;</div>

# %%
df.shape
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[95]: (20584, 5)</div>

# %% [markdown]
# ## Relationship between Cases & Deaths

# %%
# To allow us to print out plots
# %matplotlib inline
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Filter to 2020-05-01
df_05_01 = df[df["date"] == "2020-05-01"]

ax = df_05_01.plot(x="cases", y="deaths", kind="scatter", 
                   figsize=(12,8), s=100, title="Deaths vs Cases on 2020-05-01 - All States")

df_05_01[["cases", "deaths", "state"]].apply(lambda row: ax.text(*row), axis=1);

# %% [markdown]
# ## New York & New Jersey are Outliers

# %%
# Filter to states that are NOT New York and NOT New Jersey
not_ny = df[(df["state"] != "New York") & (df["state"] != "New Jersey")]
not_ny.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[98]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>date</th>
#       <th>state</th>
#       <th>fips</th>
#       <th>cases</th>
#       <th>deaths</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2020-01-21</td>
#       <td>Washington</td>
#       <td>53</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2020-01-22</td>
#       <td>Washington</td>
#       <td>53</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2020-01-23</td>
#       <td>Washington</td>
#       <td>53</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2020-01-24</td>
#       <td>Illinois</td>
#       <td>17</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2020-01-24</td>
#       <td>Washington</td>
#       <td>53</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Filter to 2020-05-01
not_ny_05_01 = not_ny[not_ny["date"] == "2020-05-01"]

ax = not_ny_05_01.plot(x="cases", y="deaths", kind="scatter", 
                   figsize=(12,8), s=50, title="Deaths vs Cases on 2020-05-01 - All States but NY and NJ")

not_ny_05_01[["cases", "deaths", "state"]].apply(lambda row: ax.text(*row), axis=1);

# %% [markdown]
# ## New York verus California COVID-19 deaths comparison

# %%
df_ny_cali = df[(df["state"] == "New York") | (df["state"] == "California")]

# Let's pivot our df_ny_cali DataFrame so that we can plot deaths over time for both states
df_ny_cali_pivot = df_ny_cali.pivot(index='date', columns='state', values='deaths').fillna(0)
df_ny_cali_pivot=df_ny_cali_pivot.astype(int)
df_ny_cali_pivot
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[100]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>state</th>
#       <th>California</th>
#       <th>New York</th>
#     </tr>
#     <tr>
#       <th>date</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2020-01-25</th>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2020-01-26</th>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2020-01-27</th>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2020-01-28</th>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2020-01-29</th>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>2021-03-07</th>
#       <td>54217</td>
#       <td>47857</td>
#     </tr>
#     <tr>
#       <th>2021-03-08</th>
#       <td>54377</td>
#       <td>47921</td>
#     </tr>
#     <tr>
#       <th>2021-03-09</th>
#       <td>54620</td>
#       <td>48000</td>
#     </tr>
#     <tr>
#       <th>2021-03-10</th>
#       <td>54877</td>
#       <td>48092</td>
#     </tr>
#     <tr>
#       <th>2021-03-11</th>
#       <td>55132</td>
#       <td>48208</td>
#     </tr>
#   </tbody>
# </table>
# <p>412 rows × 2 columns</p>
# </div>

# %%
df_ny_cali_pivot.plot.line(title="Deaths 2020-01-25 to 2020-05-01 - CA and NY", figsize=(12,8))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[101]: </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;matplotlib.axes._subplots.AxesSubplot at 0x7f99023f55b0&gt;</div>

# %% [markdown]
# ## Train-Test Split
#
# ![](https://brookewenig.com/img/IntroML/trainTest.png)

# %% [markdown]
# Because this is temporal data, instead of doing a random split, we will use data from March 1 to April 7 to train our model, and test our model by predicting values for April 8 - 14.

# %%
train_df = df[(df["date"] >= "2020-03-01") & (df["date"] <= "2020-04-07")]
test_df = df[df["date"] > "2020-04-07"]

X_train = train_df[["cases"]]
y_train = train_df["deaths"]

X_test = test_df[["cases"]]
y_test = test_df["deaths"]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Linear Regression
#
# * Goal: Find the line of best fit
# $$\hat{y} = w_0 + w_1x$$
#
# $$\{y} ≈ \hat{y} + ϵ$$
# * *x*: feature
# * *y*: label
#
# ![](https://miro.medium.com/max/640/1*LEmBCYAttxS6uI6rEyPLMQ.png)

# %% [markdown]
# Here we will be fitting a [LinearRegression](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html) model from scikit-learn.

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression().fit(X_train, y_train)
print(f"num_deaths = {lr.intercept_:.4f} + {lr.coef_[0]:.4f}*cases")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">num_deaths = -16.6442 + 0.0359*cases
# </div>

# %% [markdown]
# Hmmm... if we have no cases, then there should be no deaths caused by COVID-19, so let's set the intercept to be 0.

# %%
lr = LinearRegression(fit_intercept=False).fit(X_train, y_train)
print(f"num_deaths = {lr.coef_[0]:.4f}*cases")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">num_deaths = 0.0355*cases
# </div>

# %% [markdown]
# So this model is implying that there is a 2.9% mortality rate in our dataset. But we know that some states have higher mortality rates than others. Let's include the state as a feature!

# %% [markdown]
# Voila! You have successfully built a machine learning pipeline using scikit-learn!
#
# To keep exploring with scikit-learn, checkout the datasets at [UCI ML Repository](https://archive.ics.uci.edu/ml/index.php) and [Kaggle](https://www.kaggle.com/)!
